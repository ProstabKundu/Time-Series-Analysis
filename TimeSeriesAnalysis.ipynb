# %%
# !pip install pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
import datetime

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
tesla = yf.Ticker("TSLA")
tesla_df = tesla.history(period="max")
print(tesla_df)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-01-13 00:00:00-05:00  116.550003  122.629997  115.599998  122.400002
# 2023-01-17 00:00:00-05:00  125.699997  131.699997  125.019997  131.490005
# 2023-01-18 00:00:00-05:00  136.559998  136.679993  127.010002  128.779999
# 2023-01-19 00:00:00-05:00  127.260002  129.990005  124.309998  127.169998
# 2023-01-20 00:00:00-05:00  128.679993  133.509995  127.349998  133.419998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
type(tesla_df)
# Out:
# pandas.core.frame.DataFrame

# %%
tesla_df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-13 00:00:00-05:00  116.550003  122.629997  115.599998  122.400002
# 2023-01-17 00:00:00-05:00  125.699997  131.699997  125.019997  131.490005
# 2023-01-18 00:00:00-05:00  136.559998  136.679993  127.010002  128.779999
# 2023-01-19 00:00:00-05:00  127.260002  129.990005  124.309998  127.169998
# 2023-01-20 00:00:00-05:00  128.679993  133.509995  127.349998  133.419998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-01-13 00:00:00-05:00  180439300        0.0           0.0
# 2023-01-17 00:00:00-05:00  186477000        0.0           0.0
# 2023-01-18 00:00:00-05:00  195680300        0.0           0.0
# 2023-01-19 00:00:00-05:00  170291900        0.0           0.0
# 2023-01-20 00:00:00-05:00  138429900        0.0           0.0

# %%
tesla_df['High'].plot(figsize= (12,4) )

# %%
tesla_df['High'].plot(xlim = ['2020-01-01','2023-01-01'],figsize= (12,4) )

# %%
tesla_df['High'].plot(xlim = ['2020-01-01','2023-01-01'],ylim = [0,500],figsize= (12,4) )

# %%
tesla_df['High'].plot(xlim = ['2020-01-01','2023-01-01'],ylim = [0,500],figsize= (12,4),c = 'green',ls = '--')

# %%
tesla_df.index
# Out:
# DatetimeIndex(['2010-06-29 00:00:00-04:00', '2010-06-30 00:00:00-04:00',
#                '2010-07-01 00:00:00-04:00', '2010-07-02 00:00:00-04:00',
#                '2010-07-06 00:00:00-04:00', '2010-07-07 00:00:00-04:00',
#                '2010-07-08 00:00:00-04:00', '2010-07-09 00:00:00-04:00',
#                '2010-07-12 00:00:00-04:00', '2010-07-13 00:00:00-04:00',
#                ...
#                '2023-01-06 00:00:00-05:00', '2023-01-09 00:00:00-05:00',
#                '2023-01-10 00:00:00-05:00', '2023-01-11 00:00:00-05:00',
#                '2023-01-12 00:00:00-05:00', '2023-01-13 00:00:00-05:00',
#                '2023-01-17 00:00:00-05:00', '2023-01-18 00:00:00-05:00',
#                '2023-01-19 00:00:00-05:00', '2023-01-20 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=3163, freq=None)

# %%
index = tesla_df.loc['2020-01-01': '2023-01-19'].index

# %%
share_open = tesla_df.loc['2020-01-01':'2023-01-19']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02 00:00:00-05:00     28.299999
# 2020-01-03 00:00:00-05:00     29.366667
# 2020-01-06 00:00:00-05:00     29.364668
# 2020-01-07 00:00:00-05:00     30.760000
# 2020-01-08 00:00:00-05:00     31.580000
#                                 ...
# 2023-01-12 00:00:00-05:00    122.559998
# 2023-01-13 00:00:00-05:00    116.550003
# 2023-01-17 00:00:00-05:00    125.699997
# 2023-01-18 00:00:00-05:00    136.559998
# 2023-01-19 00:00:00-05:00    127.260002
# Name: Open, Length: 768, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
tesla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3163 entries, 2010-06-29 00:00:00-04:00 to 2023-01-20 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          3163 non-null   float64
#  1   High          3163 non-null   float64
#  2   Low           3163 non-null   float64
#  3   Close         3163 non-null   float64
#  4   Volume        3163 non-null   int64
#  5   Dividends     3163 non-null   float64
#  6   Stock Splits  3163 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 326.7 KB

# %%
tesla_df = tesla_df.reset_index()

# %%
tesla_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
tesla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3163 entries, 0 to 3162
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3163 non-null   datetime64[ns, America/New_York]
#  1   Open          3163 non-null   float64
#  2   High          3163 non-null   float64
#  3   Low           3163 non-null   float64
#  4   Close         3163 non-null   float64
#  5   Volume        3163 non-null   int64
#  6   Dividends     3163 non-null   float64
#  7   Stock Splits  3163 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 197.8 KB

# %%
tesla_df.set_index(tesla_df['Date'])
# Out:
#                                                Date        Open        High  \
# Date
# 2010-06-29 00:00:00-04:00 2010-06-29 00:00:00-04:00    1.266667    1.666667
# 2010-06-30 00:00:00-04:00 2010-06-30 00:00:00-04:00    1.719333    2.028000
# 2010-07-01 00:00:00-04:00 2010-07-01 00:00:00-04:00    1.666667    1.728000
# 2010-07-02 00:00:00-04:00 2010-07-02 00:00:00-04:00    1.533333    1.540000
# 2010-07-06 00:00:00-04:00 2010-07-06 00:00:00-04:00    1.333333    1.333333
# ...                                             ...         ...         ...
# 2023-01-13 00:00:00-05:00 2023-01-13 00:00:00-05:00  116.550003  122.629997
# 2023-01-17 00:00:00-05:00 2023-01-17 00:00:00-05:00  125.699997  131.699997
# 2023-01-18 00:00:00-05:00 2023-01-18 00:00:00-05:00  136.559998  136.679993
# 2023-01-19 00:00:00-05:00 2023-01-19 00:00:00-05:00  127.260002  129.990005
# 2023-01-20 00:00:00-05:00 2023-01-20 00:00:00-05:00  128.679993  133.509995
#
# ...

# %%
tesla_df.set_index('Date',drop = True)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-01-13 00:00:00-05:00  116.550003  122.629997  115.599998  122.400002
# 2023-01-17 00:00:00-05:00  125.699997  131.699997  125.019997  131.490005
# 2023-01-18 00:00:00-05:00  136.559998  136.679993  127.010002  128.779999
# 2023-01-19 00:00:00-05:00  127.260002  129.990005  124.309998  127.169998
# 2023-01-20 00:00:00-05:00  128.679993  133.509995  127.349998  133.419998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tesla_df.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 1, 21, 15, 1, 59, 282157)

# %%
def add_num(num1,num2):
  return num1 + num2

# %%
num1 = 20
num2 = 30
start_time = datetime.now()
add_num(num1,num2)
end_time = datetime.now()
print(end_time - start_time)
# Out:
# 0:00:00.000036

# %%
date = datetime(2021,11,21)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %%
date.month
# Out:
# 11

# %%
tesla_df.set_index('Date',inplace = True)

# %%
tesla_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-01-13 00:00:00-05:00  116.550003  122.629997  115.599998  122.400002
# 2023-01-17 00:00:00-05:00  125.699997  131.699997  125.019997  131.490005
# 2023-01-18 00:00:00-05:00  136.559998  136.679993  127.010002  128.779999
# 2023-01-19 00:00:00-05:00  127.260002  129.990005  124.309998  127.169998
# 2023-01-20 00:00:00-05:00  128.679993  133.509995  127.349998  133.419998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tesla_df.resample(rule = 'A').min()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-12-31 00:00:00-05:00    1.076000    1.108667    0.998667    1.053333
# 2011-12-31 00:00:00-05:00    1.452000    1.484667    1.407333    1.455333
# 2012-12-31 00:00:00-05:00    1.774667    1.790000    1.509333    1.519333
# 2013-12-31 00:00:00-05:00    2.205333    2.225333    2.140667    2.194000
# 2014-12-31 00:00:00-05:00    9.366667    9.800000    9.111333    9.289333
# 2015-12-31 00:00:00-05:00   12.388667   12.619333   12.093333   12.333333
# 2016-12-31 00:00:00-05:00    9.488000   10.331333    9.403333    9.578000
# 2017-12-31 00:00:00-05:00   14.316667   14.688667   14.064000   14.466000
# 2018-12-31 00:00:00-05:00   16.851999   17.355333   16.306000   16.704000
# 2019-12-31 00:00:00-05:00   12.073333   12.445333   11.799333   11.931333
# 2020-12-31 00:00:00-05:00   24.980000   26.990667   23.367332   24.081333
# 2021-12-31 00:00:00-05:00  184.183334  188.736664  179.830002  187.666672
# ...

# %%
tesla_df.resample(rule = 'A').max()['High'].plot()

# %%
tesla_df.resample(rule = 'QS').max()['High'].plot();

# %%
tesla_df.resample(rule = 'W').max()['High'].plot()

# %%
tesla_df.resample(rule = 'W').max()['High'].plot(kind = 'bar',figsize = (30,12))

# %%
tesla_df['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29 00:00:00-04:00         NaN
# 2010-06-30 00:00:00-04:00         NaN
# 2010-07-01 00:00:00-04:00         NaN
# 2010-07-02 00:00:00-04:00         NaN
# 2010-07-06 00:00:00-04:00         NaN
# 2010-07-07 00:00:00-04:00         NaN
# 2010-07-08 00:00:00-04:00         NaN
# 2010-07-09 00:00:00-04:00         NaN
# 2010-07-12 00:00:00-04:00         NaN
# 2010-07-13 00:00:00-04:00    1.421333
# 2010-07-14 00:00:00-04:00    1.389000
# 2010-07-15 00:00:00-04:00    1.329533
# 2010-07-16 00:00:00-04:00    1.298733
# 2010-07-19 00:00:00-04:00    1.293067
# 2010-07-20 00:00:00-04:00    1.305400
# 2010-07-21 00:00:00-04:00    1.333867
# 2010-07-22 00:00:00-04:00    1.358733
# 2010-07-23 00:00:00-04:00    1.383133
# 2010-07-26 00:00:00-04:00    1.406000
# 2010-07-27 00:00:00-04:00    1.422933
# Name: High, dtype: float64

# %%
tesla_df['Open : 30 days rolling'] = tesla_df['Open'].rolling(30).mean()

# %%
tesla_df.head(31)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
# 2010-07-07 00:00:00-04:00  1.093333  1.108667  0.998667  1.053333  103825500
# 2010-07-08 00:00:00-04:00  1.076000  1.168000  1.038000  1.164000  115671000
# 2010-07-09 00:00:00-04:00  1.172000  1.193333  1.103333  1.160000   60759000
# 2010-07-12 00:00:00-04:00  1.196667  1.204667  1.133333  1.136667   33037500
# 2010-07-13 00:00:00-04:00  1.159333  1.242667  1.126667  1.209333   40201500
# 2010-07-14 00:00:00-04:00  1.196000  1.343333  1.184000  1.322667   62928000
# ...

# %%
tesla_df[['Open','Open : 30 days rolling']].plot(figsize = (12,5));

# %%
import yfinance as yf
microsoft = yf.Ticker("MSFT")
microsoft_df = microsoft.history(start='2017-01-01',end= '2022-01-01')
print(microsoft_df)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2017-01-03 00:00:00-05:00   57.838810   57.884867   57.230854   57.645370
# 2017-01-04 00:00:00-05:00   57.553262   57.801972   57.221648   57.387455
# 2017-01-05 00:00:00-05:00   57.286128   57.719068   57.138745   57.387455
# 2017-01-06 00:00:00-05:00   57.387445   58.170422   57.147948   57.884865
# 2017-01-09 00:00:00-05:00   57.811186   58.105956   57.608536   57.700649
# ...                               ...         ...         ...         ...
# 2021-12-27 00:00:00-05:00  332.345865  339.300716  332.316144  339.270996
# 2021-12-28 00:00:00-05:00  339.964509  340.618386  337.160794  338.082153
# 2021-12-29 00:00:00-05:00  338.131645  341.103795  336.526688  338.775635
# 2021-12-30 00:00:00-05:00  338.735997  339.944673  335.674686  336.170044
# 2021-12-31 00:00:00-05:00  335.367579  336.209664  332.732268  333.197906
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
microsoft_df['Open'].plot()

# %%
microsoft_df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2017-01-03 00:00:00-05:00  57.838810  57.884867  57.230854  57.645370
# 2017-01-04 00:00:00-05:00  57.553262  57.801972  57.221648  57.387455
# 2017-01-05 00:00:00-05:00  57.286128  57.719068  57.138745  57.387455
# 2017-01-06 00:00:00-05:00  57.387445  58.170422  57.147948  57.884865
# 2017-01-09 00:00:00-05:00  57.811186  58.105956  57.608536  57.700649
#
#                              Volume  Dividends  Stock Splits
# Date
# 2017-01-03 00:00:00-05:00  20694100        0.0           0.0
# 2017-01-04 00:00:00-05:00  21340000        0.0           0.0
# 2017-01-05 00:00:00-05:00  24876000        0.0           0.0
# 2017-01-06 00:00:00-05:00  19922900        0.0           0.0
# 2017-01-09 00:00:00-05:00  20382700        0.0           0.0

# %%
microsoft_df.reset_index()
# Out:
#                           Date        Open        High         Low  \
# 0    2017-01-03 00:00:00-05:00   57.838810   57.884867   57.230854
# 1    2017-01-04 00:00:00-05:00   57.553262   57.801972   57.221648
# 2    2017-01-05 00:00:00-05:00   57.286128   57.719068   57.138745
# 3    2017-01-06 00:00:00-05:00   57.387445   58.170422   57.147948
# 4    2017-01-09 00:00:00-05:00   57.811186   58.105956   57.608536
# ...                        ...         ...         ...         ...
# 1254 2021-12-27 00:00:00-05:00  332.345865  339.300716  332.316144
# 1255 2021-12-28 00:00:00-05:00  339.964509  340.618386  337.160794
# 1256 2021-12-29 00:00:00-05:00  338.131645  341.103795  336.526688
# 1257 2021-12-30 00:00:00-05:00  338.735997  339.944673  335.674686
# 1258 2021-12-31 00:00:00-05:00  335.367579  336.209664  332.732268
#
#            Close    Volume  Dividends  Stock Splits
# 0      57.645370  20694100        0.0           0.0
# 1      57.387455  21340000        0.0           0.0
# ...

# %%
microsoft_df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-27 00:00:00-05:00  332.345865  339.300716  332.316144  339.270996
# 2021-12-28 00:00:00-05:00  339.964509  340.618386  337.160794  338.082153
# 2021-12-29 00:00:00-05:00  338.131645  341.103795  336.526688  338.775635
# 2021-12-30 00:00:00-05:00  338.735997  339.944673  335.674686  336.170044
# 2021-12-31 00:00:00-05:00  335.367579  336.209664  332.732268  333.197906
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-12-27 00:00:00-05:00  19947000        0.0           0.0
# 2021-12-28 00:00:00-05:00  15661500        0.0           0.0
# 2021-12-29 00:00:00-05:00  15042000        0.0           0.0
# 2021-12-30 00:00:00-05:00  15994500        0.0           0.0
# 2021-12-31 00:00:00-05:00  18000800        0.0           0.0

# %%
microsoft_df.resample(rule='A').max()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2017-12-31 00:00:00-05:00   82.042203   82.400053   81.204078   81.787941
# 2018-12-31 00:00:00-05:00  110.098704  110.823667  109.631296  110.279953
# 2019-12-31 00:00:00-05:00  155.014476  155.111700  153.818696  154.538116
# 2020-12-31 00:00:00-05:00  224.665309  228.183248  222.783916  226.997543
# 2021-12-31 00:00:00-05:00  341.420804  346.423942  339.023310  339.924835
#
#                               Volume  Dividends  Stock Splits
# Date
# 2017-12-31 00:00:00-05:00   71066700       0.42           0.0
# 2018-12-31 00:00:00-05:00  111242100       0.46           0.0
# 2019-12-31 00:00:00-05:00   55636400       0.51           0.0
# 2020-12-31 00:00:00-05:00   97012700       0.56           0.0
# 2021-12-31 00:00:00-05:00   69870600       0.62           0.0

# %%
microsoft_df.loc[microsoft_df['Open'] == microsoft_df.resample(rule='A').max()['Open'].max()]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-11-22 00:00:00-05:00  341.420804  346.423942  336.397863  336.675262
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-11-22 00:00:00-05:00  31031100        0.0           0.0

# %%
microsoft_df.loc[microsoft_df['Open'] == microsoft_df.resample(rule='A').max()['Open'].min()].index.date
# Out:
# array([datetime.date(2017, 12, 18)], dtype=object)
